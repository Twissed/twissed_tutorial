# %% [markdown]
# # twissed
#
# * Author: D. Minenna
# * Date: January 2024
#
# Tutorial on using the twissed package.
# In this notebook, we are presenting the beam function from smilei simulations.
#
# ## SMILEI Warning
#
# **Warning:** skypiea use $z$ as the longitudinal axis, therefore, $x$ and $z$ axis are inverted compared to SMILEI
#
# ## Import
# The import of the package is done by the command:
# ```python
# import twissed
# ```

# %%
# twissed
import twissed

# Select colormaps
cm = twissed.Cmap()

# %% [markdown]
# For fbpic or smilei simulations, we can check the presence of files in the defined directory

# %%
import os

# Selection of the directory with data
directory = os.getcwd() + '/data/SMILEI'

# Find all timesteps
steps = twissed.Steps()
steps.find_data(directory=directory,source='happi',verbose=True)
# Out:
# Loaded simulation '/mnt/c/Minenna/Programmation/Twissed_tutorial/data/SMILEI'
# Scanning for Scalar diagnostics
# Scanning for Field diagnostics
# Scanning for Probe diagnostics
# Scanning for ParticleBinning diagnostics
# Scanning for RadiationSpectrum diagnostics
# Scanning for Performance diagnostics
# Scanning for Screen diagnostics
# Scanning for Tracked particle diagnostics
# timesteps: [     0.   1000.   2000.   3000.   4000.   5000.   6000.   7000.   8000.
#    9000.  10000.  11000.  12000.  13000.  14000.  15000.  16000.  17000.
#   18000.  19000.  20000.  21000.  22000.  23000.  24000.  25000.  26000.
#   27000.  28000.  29000.  30000.  31000.  32000.  33000.  34000.  35000.
#   36000.  37000.  38000.  39000.  40000.  41000.  42000.  43000.  44000.
#   45000.  46000.  47000.  48000.  49000.  50000.  51000.  52000.  53000.
#   54000.  55000.  56000.  57000.  58000.  59000.  60000.  61000.  62000.
#   63000.  64000.  65000.  66000.  67000.  68000.  69000.  70000.  71000.
#   72000.  73000.  74000.  75000.  76000.  77000.  78000.  79000.  80000.
#   81000.  82000.  83000.  84000.  85000.  86000.  87000.  88000.  89000.
#   90000.  91000.  92000.  93000.  94000.  95000.  96000.  97000.  98000.
#   99000. 100000. 101000. 102000. 103000. 104000. 105000. 106000. 107000.
#  108000. 109000. 110000. 111000. 112000. 113000. 114000. 115000. 116000.
#  117000. 118000. 119000. 120000. 121000.]
# Loaded simulation '/mnt/c/Minenna/Programmation/Twissed_tutorial/data/SMILEI'
# Scanning for Scalar diagnostics
# Scanning for Field diagnostics
# Scanning for Probe diagnostics
# Scanning for ParticleBinning diagnostics
# Scanning for RadiationSpectrum diagnostics
# Scanning for Performance diagnostics
# Scanning for Screen diagnostics
# Scanning for Tracked particle diagnostics
# timesteps: [     0.   2000.   4000.   6000.   8000.  10000.  12000.  14000.  16000.
#   18000.  20000.  22000.  24000.  26000.  28000.  30000.  32000.  34000.
#   36000.  38000.  40000.  42000.  44000.  46000.  48000.  50000.  52000.
#   54000.  56000.  58000.  60000.  62000.  64000.  66000.  68000.  70000.
#   72000.  74000.  76000.  78000.  80000.  82000.  84000.  86000.  88000.
#   90000.  92000.  94000.  96000.  98000. 100000. 102000. 104000. 106000.
#  108000. 110000. 112000. 114000. 116000. 118000. 120000.]
# Loaded simulation '/mnt/c/Minenna/Programmation/Twissed_tutorial/data/SMILEI'
# Scanning for Scalar diagnostics
# Scanning for Field diagnostics
# Scanning for Probe diagnostics
# Scanning for ParticleBinning diagnostics
# Scanning for RadiationSpectrum diagnostics
# Scanning for Performance diagnostics
# Scanning for Screen diagnostics
# Scanning for Tracked particle diagnostics
# WARNING: units unknown: L_r
# WARNING: units unknown: L_r
# WARNING: units unknown: L_r
# WARNING: units unknown: P_r
# WARNING: units unknown: P_r
# WARNING: units unknown: P_r
# WARNING: units unknown: N_r * L_r^3
# WARNING: units unknown: L_r
# timesteps: [     0   5000  10000  15000  20000  25000  30000  35000  40000  45000
#   50000  55000  60000  65000  70000  75000  80000  85000  90000  95000
#  100000 105000 110000 115000 120000]

# %% [markdown]
# Now we create the **step** object. It will contain all the information about the beam at a given timestep. We can create several step objects per species.

# %%
# Get timesteps for particles
timesteps_particles = twissed.get_happi_timesteps_TrackParticles(directory)
# Out:
# Loaded simulation '/mnt/c/Minenna/Programmation/Twissed_tutorial/data/SMILEI'
# Scanning for Scalar diagnostics
# Scanning for Field diagnostics
# Scanning for Probe diagnostics
# Scanning for ParticleBinning diagnostics
# Scanning for RadiationSpectrum diagnostics
# Scanning for Performance diagnostics
# Scanning for Screen diagnostics
# Scanning for Tracked particle diagnostics
# WARNING: units unknown: L_r
# WARNING: units unknown: L_r
# WARNING: units unknown: L_r
# WARNING: units unknown: P_r
# WARNING: units unknown: P_r
# WARNING: units unknown: P_r
# WARNING: units unknown: N_r * L_r^3
# WARNING: units unknown: L_r

# %%
# timestep selection
timestep = timesteps_particles[-1]

#Creation of the step class
step = twissed.Step()

# Read data 
step = steps.read_beam(step,timestep,species='electronfromion',Disordered =False) #bckgelectron

# Print attributs obtained
print(step.keys())
# Out:
# Loaded simulation '/mnt/c/Minenna/Programmation/Twissed_tutorial/data/SMILEI'
# Scanning for Scalar diagnostics
# Scanning for Field diagnostics
# Scanning for Probe diagnostics
# Scanning for ParticleBinning diagnostics
# Scanning for RadiationSpectrum diagnostics
# Scanning for Performance diagnostics
# Scanning for Screen diagnostics
# Scanning for Tracked particle diagnostics
# WARNING: units unknown: L_r
# WARNING: units unknown: L_r
# WARNING: units unknown: L_r
# WARNING: units unknown: P_r
# WARNING: units unknown: P_r
# WARNING: units unknown: P_r
# WARNING: units unknown: N_r * L_r^3
# WARNING: units unknown: L_r
# ['verbose', 'dt', 'timestep', 'time', 'species', 'w', 'ux', 'uy', 'uz', 'x', 'y', 'z', 'g', 'Ek', 'vz', 'charge', 'N', 'Ek_avg', 'Ek_med', 'Ek_std', 'Ek_mad', 'Ek_std_perc', 'Ek_mad_perc', 'g_avg', 'g_med', 'g_std', 'g_mad', 'sigma_x', 'sigma_y', 'sigma_z', 'sigma_ux', 'sigma_uy', 'sigma_uz', 'sigma_Ek', 'betaz_avg', 'p', 'p_avg', 'dp', 'dp_avg', 'sigma_dp', 'xp', 'yp', 'sigma_xp', 'sigma_yp', 'x_divergence', 'y_divergence', 'x_avg', 'y_avg', 'z_avg', 'xx_avg', 'yy_avg', 'ux_avg', 'uy_avg', 'uz_avg', 'xp_avg', 'yp_avg', 'xpxp_avg', 'ypyp_avg', 'xxp_avg', 'yyp_avg', 'emit_rms_x', 'emit_rms_y', 'emit_norm_rms_x', 'emit_norm_rms_y', 'beta_x', 'beta_y', 'gamma_x', 'gamma_y', 'alpha_x', 'alpha_y', 'xy_avg', 'xyp_avg', 'yxp_avg', 'xpyp_avg', 'xz_avg', 'xdp_avg', 'zxp_avg', 'xpdp_avg', 'yz_avg', 'ydp_avg', 'zyp_avg', 'ypdp_avg', 'zz_avg', 'zdp_avg', 'dpdp_avg', 'sigma_matrix', 'emit_rms_z', 'emit_norm_rms_z', 'beta_z', 'gamma_z', 'alpha_z', 'emit_norm_rms_4D', 'emit_norm_rms_6D', 'x_dispersion', 'y_dispersion', 'Ek_hist_yaxis', 'Ek_hist_xaxis', 'Ek_hist_peak', 'Ek_hist_fwhm']

# %% [markdown]
# These are examples of what you get and what you can do with the step class. The default unit is always the same but you can convert it with the function

# %%
print(f"N particle: {step.N}")
print(f"Positions {step.x} [m]")
step.print('emit_norm_rms_y')
step.print('sigma_x')
step.print('charge')
print(f"Convert x in um: {step.convert('x','um')}")
# Out:
# N particle: 759982
# Positions [ 2.27356552e-06  2.94806907e-06 -5.53980529e-07 ...  1.28583679e-06
#  -5.60820058e-07  4.02455956e-07] [m]
# 3.1674395120318195 [pi.mm.mrad], Normalized trace emittance 1-rms $\gamma \beta \epsilon_{yy'}$ in y
# 2.327758616417028e-06 [m], RMS size in x.
# 137.9337660759027 [pC], Total charge of the beam. For electrons : $Q = (\sum_i w_i e) / 1e-12
# Convert x in um: [ 2.27356552  2.94806907 -0.55398053 ...  1.28583679 -0.56082006
#   0.40245596]

# %% [markdown]
# You can plot directly from the step class. The processing takes into account the weight of each macro-particle.

# %%
# Simple plot of the x distribution (dQ/dx). Note that x axis is convert in um with xconv. step.sigma_x is the standard deviation (bunch length) in x.
_ = step.hist1D(
    'Ek',
    dx=1,
    plot='plot',
)

# %%
_ = step.plot_beam(
    xrange=[-3*step.sigma_x*1e6,3*step.sigma_x*1e6],
    xprange=[-3*step.sigma_xp*1e3,3*step.sigma_xp*1e3],
    yrange=[-5*step.sigma_y*1e6,5*step.sigma_y*1e6],
    yprange=[-6*step.sigma_yp*1e3,6*step.sigma_yp*1e3],
    zrange=[-10,10],
    energyrange=[-3*step.sigma_Ek,3*step.sigma_Ek],
)

# %% [markdown]
# ## Fields

# %%
steps.timesteps
# Out:
# array([     0,   5000,  10000,  15000,  20000,  25000,  30000,  35000,
#         40000,  45000,  50000,  55000,  60000,  65000,  70000,  75000,
#         80000,  85000,  90000,  95000, 100000, 105000, 110000, 115000,
#        120000])

# %%
# timestep selection
timestep = steps.timesteps[11] 

# Read data 
step = steps.read_field(step,timestep,probe=0) # Can chose probe1D or 2D. 

# Print attributs obtained
print(step.keys())
# Out:
# Loaded simulation '/mnt/c/Minenna/Programmation/Twissed_tutorial/data/SMILEI'
# Scanning for Scalar diagnostics
# Scanning for Field diagnostics
# Scanning for Probe diagnostics
# Scanning for ParticleBinning diagnostics
# Scanning for RadiationSpectrum diagnostics
# Scanning for Performance diagnostics
# Scanning for Screen diagnostics
# Scanning for Tracked particle diagnostics
# WARNING: units unknown: L_r
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [29], in <cell line: 5>()
#       2 timestep = steps.timesteps[11]
#       4 # Read data
# ----> 5 step = steps.read_field(step,timestep,probe=0) # Can chose probe=1 only.
#       7 # Print attributs obtained
#       8 print(step.keys())
#
# File ~/anaconda3/lib/python3.9/site-packages/twissed/steps/steps.py:188, in Steps.read_field(self, step, timestep, **kwargs)
#     186 elif self.source == "happi":
#     187     if kwargs.get("probe", -1) == 0:
# --> 188         step = happi_probe1D(
#     189             step,
#     190             self.directory,
#     191             timestep,
#     192             self.lambda0,
#     193             self.omega0,
#     194             self.n_crit,
#     195             verbose=kwargs.get("verbose", False),
#     196         )
#     197         return step
#     199     elif self.source == "happi" and kwargs.get("probe", -1) == 1:
#
# File ~/anaconda3/lib/python3.9/site-packages/twissed/io/happi.py:94, in happi_probe1D(step, directory, timestep, lambda0, omega0, nc, **kwargs)
#      88 step.zfield = zfield
#      90 step.a01D = np.asarray(probe.Probe0("Env_E_abs", timesteps=timestep).getData())[
#      91     0, :
#      92 ]
# ---> 94 step.zfield_a0 = step.zfield[np.argmax(np.abs(step.a))]
#      96 step.a0_max = np.amax(step.a)
#      98 # Electric field in z
#
# AttributeError: 'Step' object has no attribute 'a'

# %%
step.plot_field1D(
    'zfield',
    'a01D',
    xconv='um',
    # yconv='GV/m'
)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [19], in <cell line: 1>()
# ----> 1 step.plot_field1D(
#       2     'zfield',
#       3     'a01D',
#       4     xconv='um',
#       5     # yconv='GV/m'
#       6 )
#
# AttributeError: 'NoneType' object has no attribute 'plot_field1D'

# %%
step.plot_field1D(
    'zfield',
    'Ez1D',
    xconv='um',
    yconv='GV/m'
)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [32], in <cell line: 1>()
# ----> 1 step.plot_field1D(
#       2     'zfield',
#       3     'Ez1D',
#       4     xconv='um',
#       5     yconv='GV/m'
#       6 )
#
# File ~/anaconda3/lib/python3.9/site-packages/twissed/step/plotfield.py:41, in StepPlotField.plot_field1D(self, xname, yname, xconv, yconv, xrange, yrange, ax, **kwargs)
#      29 def plot_field1D(
#      30     self,
#      31     xname: str,
#    (...)
#      38     **kwargs
#      39 ) -> None:
#      40     x = self.convert(xname, xconv)
# ---> 41     y = self.convert(yname, yconv)
#      43     if "units" in STD_DATABASE[xname]:
#      44         units_base = STD_DATABASE[xname]["units"]
#
# File ~/anaconda3/lib/python3.9/site-packages/twissed/utils/metadata.py:262, in MetaData.convert(self, name, wanted_units)
#     248 def convert(self, name: str, wanted_units: str) -> float:
#     249     """Convert a variable to another unit
#     250
#     251     # ! Experimental function. No security or generalisation implemented.
#    (...)
#     259         float: the attribute after conversion.
#     260     """
# --> 262     base_units = self.get_units(name)
#     263     if base_units == None or base_units == wanted_units or wanted_units == None:
#     264         return self.__dict__[name]
#
# File ~/anaconda3/lib/python3.9/site-packages/twissed/utils/metadata.py:123, in MetaData.get_units(self, name)
#     112 def get_units(self, name: str) -> Union[str, None]:
#     113     """Return _data of the attribute.
#     114
#     115     >>> a.get_units('x') # is equivalent to a._data['x']['units']
#    (...)
#     121         str | None: The "units" metadata. Can be None.
#     122     """
# --> 123     if "units" in self._data[name]:
#     124         return self._data[name]["units"]
#     125     else:
#
# KeyError: 'Ez1D'

# %%
# timestep selection
timestep = steps.timesteps[11] 

# Read data 
step = steps.read_field(step,timestep,probe=1)

# Print attributs obtained
print(step.keys())
# Out:
# Loaded simulation '/mnt/c/Minenna/Programmation/Twissed_tutorial/data/SMILEI'
# Scanning for Scalar diagnostics
# Scanning for Field diagnostics
# Scanning for Probe diagnostics
# Scanning for ParticleBinning diagnostics
# Scanning for RadiationSpectrum diagnostics
# Scanning for Performance diagnostics
# Scanning for Screen diagnostics
# Scanning for Tracked particle diagnostics
# Timestep 55000 not found in this diagnostic
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [30], in <cell line: 5>()
#       2 timestep = steps.timesteps[11]
#       4 # Read data
# ----> 5 step = steps.read_field(step,timestep,probe=1)
#       7 # Print attributs obtained
#       8 print(step.keys())
#
# File ~/anaconda3/lib/python3.9/site-packages/twissed/steps/steps.py:200, in Steps.read_field(self, step, timestep, **kwargs)
#     197     return step
#     199 elif self.source == "happi" and kwargs.get("probe", -1) == 1:
# --> 200     step = happi_probe2D(
#     201         step,
#     202         self.directory,
#     203         timestep,
#     204         self.lambda0,
#     205         self.omega0,
#     206         self.n_crit,
#     207         verbose=kwargs.get("verbose", False),
#     208     )
#     209     return step
#
# File ~/anaconda3/lib/python3.9/site-packages/twissed/io/happi.py:136, in happi_probe2D(step, directory, timestep, lambda0, omega0, nc, **kwargs)
#     131 probe = S.Probe
#     133 step = read_happi_time(step, S, omega0, timestep)
#     135 step.zfield_moved = (
# --> 136     probe.Probe1("Env_E_abs", timesteps=timestep).getXmoved(timestep)
#     137     * lambda0
#     138     / (2 * np.pi)
#     139 )
#     140 zfield = (
#     141     probe.Probe1("Env_E_abs", timesteps=timestep).getAxis("axis1")
#     142     * lambda0
#     143     / (2 * np.pi)
#     144     + step.zfield_moved
#     145 )
#     146 step.zfield = zfield[:, 0]
#
# TypeError: can't multiply sequence by non-int of type 'float'

# %%
# Simple plot of the density
step.plot_field2D(
    'zfield',
    'rfield',
    'Ey2D_env',
    xconv='um',
    yconv='mm',
    zconv='TV/m',
    # cmap=cm.gist_earth,
)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [31], in <cell line: 2>()
#       1 # Simple plot of the density
# ----> 2 step.plot_field2D(
#       3     'zfield',
#       4     'rfield',
#       5     'Ey2D_env',
#       6     xconv='um',
#       7     yconv='mm',
#       8     zconv='TV/m',
#       9     # cmap=cm.gist_earth,
#      10 )
#
# File ~/anaconda3/lib/python3.9/site-packages/twissed/step/plotfield.py:145, in StepPlotField.plot_field2D(self, xname, yname, zname, xconv, yconv, zconv, xrange, yrange, vrange, ax, **kwargs)
#     142 twissed_cmap = Cmap()
#     144 x = self.convert(xname, xconv)
# --> 145 y = self.convert(yname, yconv)
#     146 z = self.convert(zname, zconv)
#     148 if "units" in STD_DATABASE[xname]:
#
# File ~/anaconda3/lib/python3.9/site-packages/twissed/utils/metadata.py:262, in MetaData.convert(self, name, wanted_units)
#     248 def convert(self, name: str, wanted_units: str) -> float:
#     249     """Convert a variable to another unit
#     250
#     251     # ! Experimental function. No security or generalisation implemented.
#    (...)
#     259         float: the attribute after conversion.
#     260     """
# --> 262     base_units = self.get_units(name)
#     263     if base_units == None or base_units == wanted_units or wanted_units == None:
#     264         return self.__dict__[name]
#
# File ~/anaconda3/lib/python3.9/site-packages/twissed/utils/metadata.py:123, in MetaData.get_units(self, name)
#     112 def get_units(self, name: str) -> Union[str, None]:
#     113     """Return _data of the attribute.
#     114
#     115     >>> a.get_units('x') # is equivalent to a._data['x']['units']
#    (...)
#     121         str | None: The "units" metadata. Can be None.
#     122     """
# --> 123     if "units" in self._data[name]:
#     124         return self._data[name]["units"]
#     125     else:
#
# KeyError: 'rfield'
